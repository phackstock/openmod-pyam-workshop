# %% [markdown]
# # Vienna openmod 2023 workshop: the *pyam* package
#
# <br>
# <img style="float: left; height: 20px; padding-left: 10px;" src="https://img.shields.io/github/license/phackstock/openmod-pyam-workshop">
# <img style="float: left; height: 20px; padding-left: 10px;" src="https://img.shields.io/badge/python-3.7_|_3.8_|_3.9-blue?logo=python&logoColor=white">
# <img style="float: left; height: 20px; padding-left: 10px;" src="https://img.shields.io/badge/code%20style-black-000000.svg">
# <br><br>
#
# Copyright (c) 2022 Daniel Huppmann; this repository is released under the [MIT License](https://github.com/phackstock/openmod-pyam-workshop/blob/main/LICENSE).
#
# ## Overview
#
# This notebook presents a number of features of the **pyam** package given as part of
# the *Vienna openmod 2023 workshop* on March 22, 2023.
#
# This tutorial is based on the advanced assignment
# of the [Modelling Lab](https://github.com/danielhuppmann/climate-risks-academy-2021),
# which was part of the *Climate Risks Academy 2021* organized by
# the European University Institute (EUI) Florence School of Banking and Finance
# in cooperation with Oliver Wyman.
#
# The slides for the related presentation are available at
# [10.5281/zenodo.7757907](https://doi.org/10.5281/zenodo.7757907).
#
# The scenario data used in this tutorial notebook is taken from
# the [NGFS Scenario Explorer hosted by IIASA](https://data.ece.iiasa.ac.at/ngfs),
# Phase 2 (June 2021).
#
# ### Requirements
#
# You can install the **pyam** package using the following command -
# note the subtle naming difference on [pypi.org](https://pypi.org/project/pyam-iamc/).
#
# ```console
# pip install pyam-iamc
# ```
#
# if you want to stay up to date with the latest **pyam** advances you can alternatively
# also install the package from GitHub directly:
#
# ```console
# pip install  git+https://github.com/iamconsortium/pyam
# ```
#
# [Read the docs](https://pyam-iamc.readthedocs.io/en/stable/install.html) for alternative installation options.

# %%
import pyam

# %% [markdown]
# ## Import and inspect the scenario data
#
# In this example we are using an *excel* file but, pyam also supports *csv* and *frictionless data*.
# Details can be found in the pyam docs [here](https://pyam-iamc.readthedocs.io/en/stable/api/io.html#input-output-file-formats).
#
# Just calling an **IamDataFrame** prints an overview of all index dimensions and coordinates.

# %%
tutorial_df = pyam.IamDataFrame("data/ngfs_data_snapshot.xlsx")
tutorial_df
# Out:
# pyam - INFO: Running in a notebook, setting up a basic logging at level INFO
# pyam.core - INFO: Reading file data/ngfs_data_snapshot.xlsx
# pyam.core - INFO: Reading meta indicators
# <class 'pyam.core.IamDataFrame'>
# Index:
#  * model    : MESSAGEix-GLOBIOM 1.1, REMIND-MAgPIE 2.1-4.2 (2)
#  * scenario : Current Policies, Delayed transition, ... Net Zero 2050 (4)
# Timeseries data coordinates:
#    region   : R5ASIA, R5LAM, R5MAF, R5OECD90+EU, R5REF, World (6)
#    variable : Emissions|CO2, Price|Carbon, Primary Energy|Biomass, ... Temperature (9)
#    unit     : EJ/yr, Mt CO2/yr, US$2010/t CO2, °C rel. to 1850-1900 (4)
#    year     : 2010, 2020, 2030, 2040, 2050, 2060, 2070, 2080, ... 2100 (10)
# Meta indicators:
#    exclude (bool) False (1)

# %% [markdown]
# Because there are more scenarios and variables than can be displayed in one line, the summary only shows a few items.
#
# We can easily display all items of an index dimension or a coordinate individually using attributes of the **IamDataFrame**.

# %%
tutorial_df.variable
# Out:
# ['Emissions|CO2',
#  'Price|Carbon',
#  'Primary Energy|Biomass',
#  'Primary Energy|Coal',
#  'Primary Energy|Gas',
#  'Primary Energy|Non-Biomass Renewables',
#  'Primary Energy|Nuclear',
#  'Primary Energy|Oil',
#  'Temperature']

# %%
tutorial_df.scenario
# Out:
# ['Current Policies',
#  'Delayed transition',
#  'Nationally Determined Contributions (NDCs)',
#  'Net Zero 2050']

# %%
tutorial_df.region
# Out:
# ['R5ASIA', 'R5LAM', 'R5MAF', 'R5OECD90+EU', 'R5REF', 'World']

# %% [markdown]
# For the remainder of this noteboook, we only use the global data from this scenario ensemble.
# Therefore, we [filter()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.filter)
# to the data of interest...

# %%
df = tutorial_df.filter(region="World")

# %% [markdown]
# ## A few simple plots
#
# As a first step to get an idea of the scenario data, let's draw some [plots](https://pyam-iamc.readthedocs.io/en/stable/api/plotting.html).
#
# Why not start with the temperature?

# %%
df.filter(variable="Temperature").plot(legend=dict(loc="outside right"))
# Out:
# /home/hackstock/Documents/code/ECEMP-pyam-tutorial/venv/lib/python3.10/site-packages/pyam/plotting.py:1073: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col, data in df.iteritems():
# <AxesSubplot: title={'center': 'region: World - variable: Temperature'}, xlabel='Year', ylabel='°C rel. to 1850-1900'>

# %% [markdown]
# Let's apply some styling by model and scenario...

# %%
df.filter(variable="Temperature").plot(color="scenario", linestyle="model", legend=dict(loc="outside right"))
# Out:
# /home/hackstock/Documents/code/ECEMP-pyam-tutorial/venv/lib/python3.10/site-packages/pyam/plotting.py:1073: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col, data in df.iteritems():
# <AxesSubplot: title={'center': 'region: World - variable: Temperature'}, xlabel='Year', ylabel='°C rel. to 1850-1900'>

# %% [markdown]
# ## Unit conversion
#
# Working with different units is a constant headache (and source of errors) when handling energy systems data.
#
# To simplify such tasks, **pyam** incorporates the [**iam-units**](https://github.com/iamconsortium/units) package,
# a community resource for units commonly used in energy-systems modelling, integrated assessment and climate research.

# %%
df_coal = df.filter(model="MESSAGEix-GLOBIOM 1.1", scenario="Current Policies", variable="Primary Energy|Coal")
df_coal.timeseries()
# Out:
#                                                                                2010  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal EJ/yr  159.418806
#
#                                                                                2020  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal EJ/yr  142.575126
#
#                                                                                2030  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal EJ/yr  134.173259
#
#                                                                                2040  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal EJ/yr  124.318015
#
#                                                                                2050  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal EJ/yr  129.804776
#
#                                                                                2060  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal EJ/yr  161.875046
#
#                                                                                2070  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal EJ/yr  195.631274
#
#                                                                                2080  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal EJ/yr  245.543344
#
#                                                                                2090  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal EJ/yr  272.100358
#
#                                                                                2100
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal EJ/yr  268.673471

# %%
df_coal.convert_unit("EJ/yr", "PWh/yr").timeseries()
# Out:
#                                                                                2010  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal PWh/yr  44.283002
#
#                                                                                2020  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal PWh/yr  39.604202
#
#                                                                               2030  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal PWh/yr  37.27035
#
#                                                                                2040  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal PWh/yr  34.532782
#
#                                                                                2050  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal PWh/yr  36.056882
#
#                                                                                2060  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal PWh/yr  44.965291
#
#                                                                                2070  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal PWh/yr  54.342021
#
#                                                                                2080  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal PWh/yr  68.206485
#
#                                                                                2090  \
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal PWh/yr  75.583433
#
#                                                                               2100
# model                 scenario         region variable            unit
# MESSAGEix-GLOBIOM 1.1 Current Policies World  Primary Energy|Coal PWh/yr  74.63152

# %% [markdown]
# The **iam-units** package also includes a module to convert different greenhouse-gas emissions
# by alternative global-warming-potential (GWP) metrics.
#
# See [this tutorial](https://pyam-iamc.readthedocs.io/en/stable/tutorials/unit_conversion.html#4.-Use-contexts-to-specify-conversion-metrics) for more information!

# %% [markdown]
# ## Computing aggregates
#
# If you look at the list of variables in the scenario data, you'll see that we initially only have sub-categories of *Primary Energy*.
#
# However, **pyam** offers a number of useful functions to aggregate (or downscale) by sectors or regions.
#
# ### Aggregation by sector
#
# By default, the [aggregate()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.aggregate) method
# takes all components of the given variable, in this case `Primary Energy|*`.<br />
# It returns a new **IamDataFrame** - and the cell displays the summary. You will see that the object has exactly one variable now.

# %%
df.aggregate("Primary Energy")
# Out:
# <class 'pyam.core.IamDataFrame'>
# Index:
#  * model    : MESSAGEix-GLOBIOM 1.1, REMIND-MAgPIE 2.1-4.2 (2)
#  * scenario : Current Policies, Delayed transition, ... Net Zero 2050 (4)
# Timeseries data coordinates:
#    region   : World (1)
#    variable : Primary Energy (1)
#    unit     : EJ/yr (1)
#    year     : 2010, 2020, 2030, 2040, 2050, 2060, 2070, 2080, ... 2100 (10)
# Meta indicators:
#    exclude (bool) False (1)

# %%
df.aggregate("Primary Energy").plot(legend=dict(loc="outside right"))
# Out:
# /home/hackstock/Documents/code/ECEMP-pyam-tutorial/venv/lib/python3.10/site-packages/pyam/plotting.py:1073: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col, data in df.iteritems():
# <AxesSubplot: title={'center': 'region: World - variable: Primary Energy'}, xlabel='Year', ylabel='EJ/yr'>

# %% [markdown]
# Or you can use the [timeseries()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.timeseries) method to show the timeseries data in wide format.

# %%
df.aggregate("Primary Energy").timeseries()
# Out:
#                                                                                                    2010  \
# model                 scenario                                   region variable       unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Primary Energy EJ/yr  537.57828
#                       Delayed transition                         World  Primary Energy EJ/yr  537.57828
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  537.57828
#                       Net Zero 2050                              World  Primary Energy EJ/yr  537.57828
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Primary Energy EJ/yr  502.19330
#                       Delayed transition                         World  Primary Energy EJ/yr  502.19330
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  502.19330
#                       Net Zero 2050                              World  Primary Energy EJ/yr  502.19330
#
#                                                                                                     2020  \
# model                 scenario                                   region variable       unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Primary Energy EJ/yr  562.670773
#                       Delayed transition                         World  Primary Energy EJ/yr  562.670773
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  562.670773
#                       Net Zero 2050                              World  Primary Energy EJ/yr  562.670773
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Primary Energy EJ/yr  559.835600
#                       Delayed transition                         World  Primary Energy EJ/yr  559.835600
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  559.835600
#                       Net Zero 2050                              World  Primary Energy EJ/yr  559.835600
#
#                                                                                                     2030  \
# model                 scenario                                   region variable       unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Primary Energy EJ/yr  610.009066
#                       Delayed transition                         World  Primary Energy EJ/yr  610.009066
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  579.226395
#                       Net Zero 2050                              World  Primary Energy EJ/yr  448.014549
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Primary Energy EJ/yr  616.908100
#                       Delayed transition                         World  Primary Energy EJ/yr  616.908100
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  605.097300
#                       Net Zero 2050                              World  Primary Energy EJ/yr  460.599200
#
#                                                                                                     2040  \
# model                 scenario                                   region variable       unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Primary Energy EJ/yr  679.793401
#                       Delayed transition                         World  Primary Energy EJ/yr  483.437699
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  618.437380
#                       Net Zero 2050                              World  Primary Energy EJ/yr  444.766431
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Primary Energy EJ/yr  654.444900
#                       Delayed transition                         World  Primary Energy EJ/yr  440.465300
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  599.555200
#                       Net Zero 2050                              World  Primary Energy EJ/yr  452.994200
#
#                                                                                                     2050  \
# model                 scenario                                   region variable       unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Primary Energy EJ/yr  748.677804
#                       Delayed transition                         World  Primary Energy EJ/yr  466.426539
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  642.742574
#                       Net Zero 2050                              World  Primary Energy EJ/yr  476.670758
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Primary Energy EJ/yr  667.490400
#                       Delayed transition                         World  Primary Energy EJ/yr  426.093100
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  564.631200
#                       Net Zero 2050                              World  Primary Energy EJ/yr  448.864300
#
#                                                                                                     2060  \
# model                 scenario                                   region variable       unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Primary Energy EJ/yr  795.166286
#                       Delayed transition                         World  Primary Energy EJ/yr  497.980871
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  665.696003
#                       Net Zero 2050                              World  Primary Energy EJ/yr  534.265839
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Primary Energy EJ/yr  668.491300
#                       Delayed transition                         World  Primary Energy EJ/yr  454.779700
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  551.220400
#                       Net Zero 2050                              World  Primary Energy EJ/yr  466.606800
#
#                                                                                                     2070  \
# model                 scenario                                   region variable       unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Primary Energy EJ/yr  885.136262
#                       Delayed transition                         World  Primary Energy EJ/yr  599.975337
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  756.934614
#                       Net Zero 2050                              World  Primary Energy EJ/yr  663.749442
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Primary Energy EJ/yr  690.516700
#                       Delayed transition                         World  Primary Energy EJ/yr  479.441300
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  563.422100
#                       Net Zero 2050                              World  Primary Energy EJ/yr  500.192000
#
#                                                                                                     2080  \
# model                 scenario                                   region variable       unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Primary Energy EJ/yr  990.275890
#                       Delayed transition                         World  Primary Energy EJ/yr  721.814635
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  834.399625
#                       Net Zero 2050                              World  Primary Energy EJ/yr  777.373240
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Primary Energy EJ/yr  730.099300
#                       Delayed transition                         World  Primary Energy EJ/yr  516.255700
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr  594.644100
#                       Net Zero 2050                              World  Primary Energy EJ/yr  530.509500
#
#                                                                                                      2090  \
# model                 scenario                                   region variable       unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Primary Energy EJ/yr  1081.006216
#                       Delayed transition                         World  Primary Energy EJ/yr   815.647454
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr   882.109397
#                       Net Zero 2050                              World  Primary Energy EJ/yr   854.593982
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Primary Energy EJ/yr   739.544800
#                       Delayed transition                         World  Primary Energy EJ/yr   547.516800
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr   605.620000
#                       Net Zero 2050                              World  Primary Energy EJ/yr   553.248800
#
#                                                                                                      2100
# model                 scenario                                   region variable       unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Primary Energy EJ/yr  1141.949042
#                       Delayed transition                         World  Primary Energy EJ/yr   878.372137
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr   927.979372
#                       Net Zero 2050                              World  Primary Energy EJ/yr   907.008422
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Primary Energy EJ/yr   739.513400
#                       Delayed transition                         World  Primary Energy EJ/yr   569.627200
#                       Nationally Determined Contributions (NDCs) World  Primary Energy EJ/yr   620.354100
#                       Net Zero 2050                              World  Primary Energy EJ/yr   581.650700

# %% [markdown]
# It is often convenient to directly append computed timeseries data to the original object.
# For that, you can use the `append=True` keyword argument.

# %%
df.aggregate("Primary Energy", append=True)

# %%
df
# Out:
# <class 'pyam.core.IamDataFrame'>
# Index:
#  * model    : MESSAGEix-GLOBIOM 1.1, REMIND-MAgPIE 2.1-4.2 (2)
#  * scenario : Current Policies, Delayed transition, ... Net Zero 2050 (4)
# Timeseries data coordinates:
#    region   : World (1)
#    variable : Emissions|CO2, Price|Carbon, Primary Energy, ... Temperature (10)
#    unit     : EJ/yr, Mt CO2/yr, US$2010/t CO2, °C rel. to 1850-1900 (4)
#    year     : 2010, 2020, 2030, 2040, 2050, 2060, 2070, 2080, ... 2100 (10)
# Meta indicators:
#    exclude (bool) False (1)

# %% [markdown]
# When displaying the variables of the **IamDataFrame** again, there is now an additional variable `Primary Energy`.

# %%
df.filter(variable="Primary Energy").data
# Out:
#                     model          scenario region        variable   unit  \
# 0   MESSAGEix-GLOBIOM 1.1  Current Policies  World  Primary Energy  EJ/yr
# 1   MESSAGEix-GLOBIOM 1.1  Current Policies  World  Primary Energy  EJ/yr
# 2   MESSAGEix-GLOBIOM 1.1  Current Policies  World  Primary Energy  EJ/yr
# 3   MESSAGEix-GLOBIOM 1.1  Current Policies  World  Primary Energy  EJ/yr
# 4   MESSAGEix-GLOBIOM 1.1  Current Policies  World  Primary Energy  EJ/yr
# ..                    ...               ...    ...             ...    ...
# 75  REMIND-MAgPIE 2.1-4.2     Net Zero 2050  World  Primary Energy  EJ/yr
# 76  REMIND-MAgPIE 2.1-4.2     Net Zero 2050  World  Primary Energy  EJ/yr
# 77  REMIND-MAgPIE 2.1-4.2     Net Zero 2050  World  Primary Energy  EJ/yr
# 78  REMIND-MAgPIE 2.1-4.2     Net Zero 2050  World  Primary Energy  EJ/yr
# 79  REMIND-MAgPIE 2.1-4.2     Net Zero 2050  World  Primary Energy  EJ/yr
#
#     year       value
# 0   2010  537.578280
# 1   2020  562.670773
# 2   2030  610.009066
# 3   2040  679.793401
# 4   2050  748.677804
# ..   ...         ...
# 75  2060  466.606800
# 76  2070  500.192000
# 77  2080  530.509500
# 78  2090  553.248800
# 79  2100  581.650700
#
# [80 rows x 7 columns]

# %% [markdown]
# ### Aggregation by region
#
# In the interest of time, the features for regional aggregation and downscaling are not shown in this notebook.
#
# Take a look at [this tutorial](https://pyam-iamc.readthedocs.io/en/stable/tutorials/aggregating_downscaling_consistency.html)
# for more information!

# %% [markdown]
# ## Categorization of scenarios by their temperature outcome
#
# We often want to categorize scenarios by some metrics or indicators.
# As an example, let us divide scenarios into groups "above 2C" and "below 2C".
#
# First, we assign **all** scenarios to the "above 2C" group,
# and then use the [categorize()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.categorize) method
# to re-assign all scenarios that satisfy certain criteria.

# %%
df.set_meta(meta="above 2C", name="warming-category")
df.to_excel("df_warming_category_meta.xlsx")

# %%
df.filter(variable="Temperature").timeseries()
# Out:
#                                                                                                               2010  \
# model                 scenario                                   region variable    unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Temperature °C rel. to 1850-1900  0.889198
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  0.889198
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  0.889198
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  0.889198
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Temperature °C rel. to 1850-1900  0.893895
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  0.893895
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  0.893895
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  0.893895
#
#                                                                                                               2020  \
# model                 scenario                                   region variable    unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Temperature °C rel. to 1850-1900  1.144961
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.144961
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  1.145318
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.147266
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Temperature °C rel. to 1850-1900  1.177163
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.177163
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  1.177262
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.178294
#
#                                                                                                               2030  \
# model                 scenario                                   region variable    unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Temperature °C rel. to 1850-1900  1.411885
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.414306
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  1.416822
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.450250
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Temperature °C rel. to 1850-1900  1.483276
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.484530
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  1.482378
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.466969
#
#                                                                                                               2040  \
# model                 scenario                                   region variable    unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Temperature °C rel. to 1850-1900  1.690337
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.698775
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  1.668852
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.580638
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Temperature °C rel. to 1850-1900  1.820651
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.770727
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  1.790175
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.589256
#
#                                                                                                               2050  \
# model                 scenario                                   region variable    unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Temperature °C rel. to 1850-1900  1.965273
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.803948
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  1.869335
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.616591
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Temperature °C rel. to 1850-1900  2.143673
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.826000
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  2.040491
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.619372
#
#                                                                                                               2060  \
# model                 scenario                                   region variable    unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Temperature °C rel. to 1850-1900  2.216190
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.817383
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  2.024416
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.596895
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Temperature °C rel. to 1850-1900  2.415560
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.805156
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  2.190271
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.603045
#
#                                                                                                               2070  \
# model                 scenario                                   region variable    unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Temperature °C rel. to 1850-1900  2.464192
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.780400
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  2.159243
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.560674
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Temperature °C rel. to 1850-1900  2.652594
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.781409
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  2.294789
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.585981
#
#                                                                                                               2080  \
# model                 scenario                                   region variable    unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Temperature °C rel. to 1850-1900  2.721895
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.718643
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  2.295594
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.543526
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Temperature °C rel. to 1850-1900  2.878548
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.757755
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  2.367370
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.573245
#
#                                                                                                               2090  \
# model                 scenario                                   region variable    unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Temperature °C rel. to 1850-1900  3.023293
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.669354
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  2.417973
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.532123
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Temperature °C rel. to 1850-1900  3.070665
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.732825
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  2.422177
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.562315
#
#                                                                                                               2100
# model                 scenario                                   region variable    unit
# MESSAGEix-GLOBIOM 1.1 Current Policies                           World  Temperature °C rel. to 1850-1900  3.334055
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.636914
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  2.524034
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.526116
# REMIND-MAgPIE 2.1-4.2 Current Policies                           World  Temperature °C rel. to 1850-1900  3.239146
#                       Delayed transition                         World  Temperature °C rel. to 1850-1900  1.709225
#                       Nationally Determined Contributions (NDCs) World  Temperature °C rel. to 1850-1900  2.461980
#                       Net Zero 2050                              World  Temperature °C rel. to 1850-1900  1.556508

# %%
df.categorize(
    "warming-category", "below 2C",
    criteria={"Temperature": {"up": 2.0}},
)
# Out:
# pyam.core - INFO: 4 scenarios categorized as `warming-category: below 2C`

# %% [markdown]
# We can inspect the assignment of categories via the `meta` attribute.

# %%
df.to_excel("df_warming_category_meta.xlsx")

# %% [markdown]
# We can now use this categorization to assign styles for the plots of other variables.

# %%
(
    df.filter(variable="Primary Energy|Gas")
    .plot(color="warming-category", linestyle="model", fill_between=True, final_ranges=True)
)
# Out:
# /home/hackstock/Documents/code/ECEMP-pyam-tutorial/venv/lib/python3.10/site-packages/pyam/plotting.py:1073: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col, data in df.iteritems():
# <AxesSubplot: title={'center': 'region: World - variable: Primary Energy|Gas'}, xlabel='Year', ylabel='EJ/yr'>

# %% [markdown]
# Of course, **pyam** also supports a lot of other plot types and styles -
# check out the [plotting gallery](https://pyam-iamc.readthedocs.io/en/stable/gallery/index.html)!

# %% [markdown]
# ## Algebraic operations
#
# **pyam** can also perform algebraic directly on the timeseries data.
#
# All algebraic-operations functions (
# [add()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.add),
# [subtract()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.subtract),
# [multiply()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.multiply),
# [divide()](https://pyam-iamc.readthedocs.io/en/stable/api/iamdataframe.html#pyam.IamDataFrame.divide)
# ) follow the syntax:
#
# ```
# df.<method>(a, b, c) => a <op> b = c
# ```
#
# If possible, **pyam** will try to keep the unit consistent during the operation.
# This feature is supported by the **pint** and the **iam-units** packages,
# see [here](https://github.com/iamconsortium/units).
#
# ## Computing the amount of primary energy that is not coal
#
# First, we subtract coal from total primary energy and draw a simple plot.
# For this section, we will use a downselected version of the scenario data that only has global values.

# %%
df.subtract("Primary Energy", "Primary Energy|Coal", "Primary Energy|Non-Coal").plot()
# Out:
# /home/hackstock/Documents/code/ECEMP-pyam-tutorial/venv/lib/python3.10/site-packages/pyam/plotting.py:1073: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col, data in df.iteritems():
# <AxesSubplot: title={'center': 'region: World - variable: Primary Energy|Non-Coal'}, xlabel='Year', ylabel='EJ/yr'>

# %% [markdown]
# ### Computing coal as a share of primary energy
#
# Next, we can also compute the share of coal relative to total primary energy, and again draw the plot.

# %%
df.divide("Primary Energy|Coal", "Primary Energy", "Share of coal").plot(legend=dict(loc="outside right"))
# Out:
# /home/hackstock/Documents/code/ECEMP-pyam-tutorial/venv/lib/python3.10/site-packages/pyam/plotting.py:1073: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col, data in df.iteritems():
# <AxesSubplot: title={'center': 'region: World - variable: Share of coal'}, xlabel='Year', ylabel='Value'>

# %% [markdown]
# Note that **pyam** has automatically changed the unit on the y-axis.
# Dividing `EJ/yr` by `EJ/yr` yiels in a dimensionless value.

# %% [markdown]
# ### Compute ratio of energy sources between different scenarios
#
# So far, we used the algebraic operations on the (default) *variable* axis.
# But **pyam** also supports these operations on any other axis of the timeseries data!
#
# Now, we compute the relative indicator between the *Net Zero 2050* and the *Current Policies* scenarios,
# and again plot the resulting timeseries data.
# For simplicity, we only perform this computation on primary-energy values (including the sub-categories)
# of the *REMIND* model.

# %%
df_pe = df.filter(model="REMIND-MAgPIE 2.1-4.2", variable="Primary Energy*")

# %%
(
    df_pe.divide("Net Zero 2050", "Current Policies", "Ratio", axis="scenario")
    .plot(legend=dict(loc="outside right"))
)
# Out:
# /home/hackstock/Documents/code/ECEMP-pyam-tutorial/venv/lib/python3.10/site-packages/pyam/plotting.py:1073: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col, data in df.iteritems():
# <AxesSubplot: title={'center': 'model: REMIND-MAgPIE 2.1-4.2 - scenario: Ratio - region: World'}, xlabel='Year', ylabel='Value'>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# As a final illustration, this tutorials shows how to use **matplotlib** and **pyam** to create several plots next to each other.

# %%
baseline = "Current Policies"
scenario = set(df.scenario) - set([baseline])

# We first create a matplotlib figure with several "axes" objects (i.e., individual plots)
fig, ax = plt.subplots(1, len(scenario), figsize=(15, 5), sharey=True)

# Then, we iterate over the axes, plotting the results for each scenario as we go along
for i, s in enumerate(scenario):
    (
        df_pe.divide(s, baseline, "Ratio", axis="scenario")
        .plot(ax=ax[i], legend=dict(loc="outside right") if i==len(scenario) - 1 else False)
    )

    # We can also modify the axes objects directly to produce a better figure
    ax[i].set_title(s)
# Out:
# /home/hackstock/Documents/code/ECEMP-pyam-tutorial/venv/lib/python3.10/site-packages/pyam/plotting.py:1073: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col, data in df.iteritems():
# /home/hackstock/Documents/code/ECEMP-pyam-tutorial/venv/lib/python3.10/site-packages/pyam/plotting.py:1073: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col, data in df.iteritems():
# /home/hackstock/Documents/code/ECEMP-pyam-tutorial/venv/lib/python3.10/site-packages/pyam/plotting.py:1073: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col, data in df.iteritems():

# %% [markdown]
# ### Retrieve data directly from a Scenario Explorer
#
# So far we have worked with downloaded data in form of Excel.
# However, it is possible to download data directly from a Scenario Explorer.
#
# To view the different databases available we use:

# %%
conn = pyam.iiasa.Connection()
# Out:
# pyam.iiasa - INFO: You are connected as user `hackstock`

# %% [markdown]
# Explore what's there for AR6:

# %%
conn = pyam.iiasa.Connection('ar6')
# Out:
# pyam.iiasa - INFO: You are connected to the IXSE_AR6 scenario explorer hosted by IIASA. If you use this data in any published format, please cite the data as provided in the explorer guidelines: https://data.ce.iiasa.ac.at/ar6-scenario-submission/#/about
# pyam.iiasa - INFO: You are connected as user `hackstock`

# %%
conn.models()
# Out:
# 0        COPPE-COFFEE 1.0
# 1           POLES ADVANCE
# 2               Reference
# 3       TIAM-Grantham 1.0
# 4       WITCH-GLOBIOM 3.1
#               ...
# 187              GCAM 4.0
# 188    EDGE-Buildings 3.0
# 189          IIASAPOP 2.0
# 190      Global TIMES 2.0
# 191             C3IAM 1.0
# Name: model, Length: 192, dtype: object

# %%
conn.scenarios()
# Out:
# 0        CD-LINKS_INDC2030i_1600
# 1                 CD-LINKS_INDCi
# 2         CD-LINKS_NDC2030i_1000
# 3                   CD-LINKS_NPi
# 4          CD-LINKS_NPi2020_1000
#                   ...
# 1413                    PEAK25-H
# 1414                    PEAK25-L
# 1415                    PEAK30-H
# 1416                    PEAK30-L
# 1417    EN_NPi2020_400f_lowBECCS
# Name: scenario, Length: 1418, dtype: object

# %% [markdown]
# Let's get some AR6 data then:

# %%
df = pyam.read_iiasa(
    'ar6',
    model='MESSAGEix*',
    variable=['Emissions|CO2', 'Primary Energy|Coal'],
    region='World',
)
# Out:
# pyam.iiasa - INFO: You are connected to the IXSE_AR6 scenario explorer hosted by IIASA. If you use this data in any published format, please cite the data as provided in the explorer guidelines: https://data.ce.iiasa.ac.at/ar6-scenario-submission/#/about
# pyam.iiasa - INFO: You are connected as user `hackstock`

# %%
df
# Out:
# <class 'pyam.core.IamDataFrame'>
# Index:
#  * model    : MESSAGEix-GLOBIOM 1.0, MESSAGEix-GLOBIOM_1.0, ... MESSAGEix-GLOBIOM_GEI 1.0 (5)
#  * scenario : CD-LINKS_INDC2030i_1600, CD-LINKS_INDCi, ... SSP2_openres_mc_50 (227)
# Timeseries data coordinates:
#    region   : World (1)
#    variable : Emissions|CO2, Primary Energy|Coal (2)
#    unit     : EJ/yr, Mt CO2/yr (2)
#    year     : 1990, 1995, 2000, 2005, 2010, 2015, 2020, 2021, ... 2110 (24)
# Meta indicators:
#    version (float64) 3.0, 1.0, 8.0, 4.0, 5.0, 2.0, nan (7)
#    harmonization (object) aneris (version: 0.2.0+11.g0beff33), nan (2)
#    Name of Person (object) Volker Krey, nan, Arnulf Grubler, ... Fei GUO (6)
#    Name of Person (model) (object) Oliver Fricko, nan, Daniel Huppmann (3)
#    Date of Entry (model) (object) 26.April 2017, ... (3)
#    ...

# %% [markdown]
# More details about downloading data directly from a Scenario Explorer can be found in the [pyam docs](https://pyam-iamc.readthedocs.io/en/stable/tutorials/iiasa_dbs.html).

# %% [markdown]
# <div class="alert alert-info">
#
# **Curious about more pyam features?** Check out the all the pyam tutorials on our [ReadTheDocs page](https://pyam-iamc.readthedocs.io/en/stable/tutorials.html)!
#
# </div>
